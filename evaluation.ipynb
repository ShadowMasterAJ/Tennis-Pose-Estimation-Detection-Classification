# %%
import os
import cv2
import torch
import numpy as np
from tqdm import tqdm
from ultralytics import YOLO
from sklearn.metrics import mean_squared_error
from dataloader import get_dataloaders
from utils.inference_utils import visualize_results
from models.tennis_conv import SimpleTennisConv, TennisConvResidual, EnhancedTennisConv 
from models.tennisnet import TennisNet
from training.config import Config

def calculate_iou(true_bbox, pred_bbox):
    """
    Calculate the Intersection over Union (IoU) of two bounding boxes.
    Parameters:
    true_bbox (list or tuple): The ground truth bounding box in the format [x1, y1, x2, y2],
                               where (x1, y1) is the top-left corner and (x2, y2) is the bottom-right corner.
    pred_bbox (list or tuple): The predicted bounding box in the format [x1, y1, x2, y2],
                               where (x1, y1) is the top-left corner and (x2, y2) is the bottom-right corner.
    Returns:
    float: The IoU of the two bounding boxes.
    """
    xA = max(true_bbox[0], pred_bbox[0])
    yA = max(true_bbox[1], pred_bbox[1])
    xB = min(true_bbox[2], pred_bbox[2])
    yB = min(true_bbox[3], pred_bbox[3])

    interArea = max(0, xB - xA) * max(0, yB - yA)
    boxAArea = (true_bbox[2] - true_bbox[0]) * (true_bbox[3] - true_bbox[1])
    boxBArea = (pred_bbox[2] - pred_bbox[0]) * (pred_bbox[3] - pred_bbox[1])

    iou = interArea / float(boxAArea + boxBArea - interArea)
    return iou

def check_keypoint_alignment(true_keypoints, pred_keypoints):
    """
    Check the alignment of predicted keypoints against true keypoints and identify potential misalignments.
    Parameters:
    true_keypoints (list of tuples): A list of tuples representing the true keypoints. Each tuple contains the (x, y) coordinates of a keypoint.
    pred_keypoints (list of tuples): A list of tuples representing the predicted keypoints. Each tuple contains the (x, y) coordinates of a keypoint.
    The function calculates the mean squared error (MSE) for each keypoint and compares it against a threshold to detect potential misalignments.
    The threshold is determined based on the mean and standard deviation of the MSE values across all keypoints.
    If the MSE for a keypoint exceeds the threshold, a message indicating potential misalignment is printed.
    Joint names considered:
    - Nose
    - Left Eye
    - Right Eye
    - Left Ear
    - Right Ear
    - Left Shoulder
    - Right Shoulder
    - Left Elbow
    - Right Elbow
    - Left Wrist
    - Right Wrist
    - Left Hip
    - Right Hip
    - Left Knee
    - Right Knee
    - Left Ankle
    - Right Ankle
    Returns:
    None
    """
    
    joint_names = [
        "Nose", "Left Eye", "Right Eye", "Left Ear", "Right Ear",
        "Left Shoulder", "Right Shoulder", "Left Elbow", "Right Elbow",
        "Left Wrist", "Right Wrist", "Left Hip", "Right Hip", "Left Knee",
        "Right Knee", "Left Ankle", "Right Ankle"
    ]

    for i, (true_kp, pred_kp) in enumerate(zip(true_keypoints, pred_keypoints)):
        mse = mean_squared_error(true_kp[:2], pred_kp[:2])
        mse_values = [mean_squared_error(t[:2], p[:2]) for t, p in zip(true_keypoints, pred_keypoints)]
        mse_mean = np.mean(mse_values)
        mse_std = np.std(mse_values)
        mse_threshold = mse_mean + 4 * mse_std  # Outlier threshold based on mean and standard deviation

        if mse >= mse_threshold:
            print(f"\n{'*'*20}Potential misalignment detected for {joint_names[i]}{'*'*20}")
            print(f"{joint_names[i]}:\t True: {true_kp},\t Pred: {pred_kp},\t MSE: {mse}\n")

def denormalize(image, mean, std):
    """
    Denormalizes an image tensor using the provided mean and standard deviation.
    Parameters:
    image (torch.Tensor): The normalized image tensor with shape (C, H, W).
    mean (list or np.array): The mean values used for normalization.
    std (list or np.array): The standard deviation values used for normalization.
    Returns:
    np.array: The denormalized image with pixel values clipped between 0 and 1.
    """
    
    mean = np.array(mean)
    std = np.array(std)
    image = image.numpy().transpose((1, 2, 0))
    image = std * image + mean
    image = np.clip(image, 0, 1)
    return image

# %%
 
def evaluate_non_temp_model(model,model_weights_path,device):
    """
    Evaluates non-temporal models on a test dataset.
    Parameters:
    model (torch.nn.Module): The neural network model to evaluate.
    model_weights_path (str): Path to the model weights file.
    device (torch.device): The device to run the evaluation on (e.g., 'cpu' or 'cuda').
    Returns:
    tuple: A tuple containing the following evaluation metrics:
        - mean_iou (float): Mean Intersection over Union (IoU) for bounding boxes.
        - mean_keypoint_error (float): Mean Squared Error (MSE) for keypoints.
        - classification_accuracy (float): Classification accuracy for the model.
    """
    
    model.to(device)
    model.eval()
    
    # Load model weights
    checkpoint = torch.load(model_weights_path, map_location=device)
    model.load_state_dict(checkpoint['state_dict'])
    json_files = os.listdir("og_dataset/annotations")
    base_path = "og_dataset"
    _, _, test_loader = get_dataloaders(json_files, base_path, batch_size=32)

    bbox_ious = []
    keypoint_errors = []
    correct_classifications = 0
    total_samples = 0

    for images, bboxes, keypoints, labels in tqdm(test_loader, desc="Evaluating"):
        images = images.to(device)  # Only take the last frame
        bboxes = bboxes.to(device)        # Only take the last frame
        keypoints = keypoints.to(device)  # Only take the last frame
        labels = labels.to(device)           # Only take the last frame
        height, width = 720, 1280
        mean = [0.485, 0.456, 0.406]
        std = [0.229, 0.224, 0.225]
        
        with torch.no_grad():
            pred_keypoints, pred_bboxes, pred_classes = model(images)
        
        pred_keypoints = pred_keypoints.cpu().numpy().reshape(-1, 18, 3)
        pred_bboxes = pred_bboxes.cpu().numpy().reshape(-1, 4)
        pred_classes = pred_classes.argmax(dim=1).cpu().numpy()
        
        for i in range(images.size(0)):
            true_keypoint = keypoints[i].cpu().numpy().reshape(-1, 3)
            true_bbox = bboxes[i].cpu().numpy().reshape(-1)
            true_class = labels[i].cpu().item()
            resized_image = denormalize(images[i].cpu(), mean, std)

            pred_keypoint = pred_keypoints[i]
            pred_bbox = pred_bboxes[i]
            pred_class = pred_classes[i]
            
            pred_keypoint *= 320  # x
            pred_bbox *= 320  # x
            
            # Calculate IoU for bounding boxes
            iou = calculate_iou(true_bbox, pred_bbox)
            bbox_ious.append(iou)
            
            # Calculate MSE for keypoints
            mse = mean_squared_error(true_keypoint[:, :2], pred_keypoint[:, :2])
            keypoint_errors.append(mse)
            
            if pred_class == true_class:
                correct_classifications += 1
            total_samples += 1
            
            # if iou < 0.1:
            #     print('IOU:',iou)
            #     print(true_bbox)
            #     print(pred_bbox)
            #     visualize_results(resized_image, true_bbox, pred_bbox, true_keypoint, pred_keypoint, yolo=0)
            # if mse > 50:
            #     print('MSE:',mse)
            #     print(true_keypoints)
            #     print(pred_keypoint)
            #     visualize_results(resized_image, true_bbox_converted, pred_bbox_converted, true_keypoints, pred_keypoint, yolo=0)

    mean_iou = np.mean(bbox_ious)
    mean_keypoint_error = np.mean(keypoint_errors)
    classification_accuracy = correct_classifications / total_samples

    print(f"\n{'*'*20} Evaluation Results {'*'*20}")
    print(f"Mean IoU: {mean_iou}")
    print(f"Mean Keypoint Error (MSE): {mean_keypoint_error}")
    print(f"Classification Accuracy: {classification_accuracy}")
    print(f"Total Samples: {total_samples}")
    print(f"{'*'*60}\n")
    
    return mean_iou, mean_keypoint_error, classification_accuracy


def evaluate_temp_model(model, model_weights_path, device):
    """
    Evaluates the performance of temporal models on a test dataset.
    Args:
        model (torch.nn.Module): The BRNN model to be evaluated.
        model_weights_path (str): Path to the model weights file.
        device (torch.device): The device (CPU or GPU) to run the evaluation on.
    Returns:
        tuple: A tuple containing:
            - mean_iou (float): The mean Intersection over Union (IoU) for bounding boxes.
            - mean_keypoint_error (float): The mean squared error (MSE) for keypoints.
            - classification_accuracy (float): The accuracy of the classification.
    The function performs the following steps:
        1. Loads the model weights.
        2. Prepares the test data loader.
        3. Iterates through the test data and makes predictions.
        4. Calculates IoU for bounding boxes, MSE for keypoints, and classification accuracy.
        5. Prints and returns the evaluation metrics.
    """
    
    model.to(device)
    model.eval()
    
    checkpoint = torch.load(model_weights_path, map_location=device)
    model.load_state_dict(checkpoint['state_dict'])
    json_files = os.listdir("og_dataset/annotations")
    base_path = "og_dataset"
    _, _, test_loader = get_dataloaders(json_files, base_path, batch_size=Config.BATCH_SIZE,sequence_length=Config.SEQ_LENGTH)

    bbox_ious = []
    keypoint_errors = []
    correct_classifications = 0
    total_samples = 0

    for sequences, bboxes, keypoints, labels in tqdm(test_loader, desc="Evaluating"):
        sequences = sequences.to(device)  # Batch of sequences
        bboxes = bboxes.to(device)
        keypoints = keypoints.to(device)
        labels = labels.to(device)
        height, width = 720, 1280
        mean = [0.485, 0.456, 0.406]
        std = [0.229, 0.224, 0.225]
        with torch.no_grad():
            pred_keypoints, pred_bboxes, pred_classes = model(sequences)

        pred_keypoints = pred_keypoints.cpu().numpy().reshape(-1, 18, 3)
        pred_bboxes = pred_bboxes.cpu().numpy().reshape(-1, 4)
        pred_classes = pred_classes.argmax(dim=1).cpu().numpy()
        
        for i in range(len(sequences)):
            true_keypoint = keypoints[i,-1].cpu().numpy().reshape(-1, 3)
            true_bbox = bboxes[i,-1].cpu().numpy().reshape(-1)
            true_class = labels[i].cpu().item()
            resized_image = denormalize(sequences[i, -1].cpu(), mean, std)

            pred_keypoint = pred_keypoints[i]
            pred_bbox = pred_bboxes[i]
            pred_class = pred_classes[i]
            
            # Calculate IoU for bounding boxes
            iou = calculate_iou(true_bbox, pred_bbox)
            bbox_ious.append(iou)
            
            # Calculate MSE for keypoints
            mse = mean_squared_error(true_keypoint[:, :2], pred_keypoint[:, :2])
            keypoint_errors.append(mse)
            
            if pred_class == true_class:
                correct_classifications += 1
            total_samples += 1
            
            # if iou < 0.1:
            #     print('IOU:', iou)
            #     print(true_bbox)
            #     print(pred_bbox)
            #     visualize_results(resized_image, true_bbox, pred_bbox, true_keypoint, pred_keypoint, yolo=0)

    mean_iou = np.mean(bbox_ious)
    mean_keypoint_error = np.mean(keypoint_errors)
    classification_accuracy = correct_classifications / total_samples

    print(f"\n{'*'*20} Evaluation Results {'*'*20}")
    print(f"Mean IoU: {mean_iou}")
    print(f"Mean Keypoint Error (MSE): {mean_keypoint_error}")
    print(f"Classification Accuracy: {classification_accuracy}")
    print(f"Total Samples: {total_samples}")
    print(f"{'*'*60}\n")
    
    return mean_iou, mean_keypoint_error, classification_accuracy

model_weights_map = {
    "TennisConvResidual": "checkpointsRes\\best_model.pth.tar",
    "SimpleTennisConv": "checkpoints_conv\\best_model.pth.tar",
    "EnhancedTennisConv": "checkpointsEnhanced\\best_model.pth.tar",
    "TennisNet": "checkpoints_net\\best_model.pth.tar",
}

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for model_name, weights_path in model_weights_map.items():
    print(f"Evaluating {model_name}...")
    model_class = globals()[model_name]
    model = model_class()
    if model_name == "TennisNet":
        mean_iou, mean_keypoint_error, classification_accuracy = evaluate_temp_model(model, weights_path, device)
    else:
        mean_iou, mean_keypoint_error, classification_accuracy = evaluate_non_temp_model(model, weights_path, device)
    
    # with open("custom_eval_results.txt", "a") as f:
    #     f.write(f"\n{'*'*20} Evaluation Results {'*'*20}\n")
    #     f.write(f"Model: {model_name}\n")
    #     f.write(f"{'-'*60}\n")
    #     f.write(f"Mean BBox IoU: {mean_iou}\n")
    #     f.write(f"Mean Keypoint Error (MSE): {mean_keypoint_error}\n")
    #     f.write(f"Classification Accuracy: {classification_accuracy}\n")
    #     f.write(f"{'*'*60}\n")
# Out:
# Evaluating TennisConvResidual...
# Initialising the model!
# Freezing the backbone layers of efficientnet_b7
# Evaluating: 100%|██████████| 10/10 [00:21<00:00,  2.15s/it]
# ******************** Evaluation Results ********************
# Mean IoU: 0.00065966989863307
# Mean Keypoint Error (MSE): 6976.83740234375
# Classification Accuracy: 0.99
# Total Samples: 300
# ************************************************************
#
# Evaluating SimpleTennisConv...
# Initialising the model!
# Freezing the backbone layers of efficientnet_b3
# Evaluating: 100%|██████████| 10/10 [00:17<00:00,  1.75s/it]
# ******************** Evaluation Results ********************
# Mean IoU: 0.5411755851056143
# Mean Keypoint Error (MSE): 263.68267822265625
# Classification Accuracy: 0.8866666666666667
# Total Samples: 300
# ************************************************************
#
# Evaluating EnhancedTennisConv...
# Freezing the backbone layers of efficientnet_b7
# Evaluating: 100%|██████████| 10/10 [00:20<00:00,  2.01s/it]
# ******************** Evaluation Results ********************
# Mean IoU: 0.6482776975064785
# Mean Keypoint Error (MSE): 93.76282501220703
# Classification Accuracy: 0.9833333333333333
# Total Samples: 300
# ************************************************************
#
# Evaluating TennisNet...
# Freezing the backbone layers of efficientnet_b3
# No overlaps found in data
# Evaluating: 100%|██████████| 9/9 [01:07<00:00,  7.45s/it]
# ******************** Evaluation Results ********************
# Mean IoU: 0.13745467391423286
# Mean Keypoint Error (MSE): 2536.89111328125
# Classification Accuracy: 0.250936329588015
# Total Samples: 267
# ************************************************************

# %%
import sys
sys.path.append('C:\\Users\\arnav\\Documents\\University\\CS 5100 Foundations of Artificial Intelligence\\Final Project\\Final Project')

def evaluate_yolo_model(model_path, test_images_path, test_labels_path, device):
    """
    Evaluates a YOLO model on a given test dataset.
    Args:
        model_path (str): Path to the YOLO model file.
        test_images_path (str): Path to the directory containing test images.
        test_labels_path (str): Path to the directory containing test labels.
        device (str): Device to run the model on (e.g., 'cpu' or 'cuda').
    Returns:
        tuple: A tuple containing:
            - mean_iou (float): Mean Intersection over Union (IoU) of the predicted bounding boxes.
            - mean_keypoint_error (float): Mean Squared Error (MSE) of the predicted keypoints.
            - classification_accuracy (float): Accuracy of the predicted classes.
    """
    
    model = YOLO(model_path).to(device)
    
    bbox_ious = []
    keypoint_errors = []
    correct_classifications = 0
    total_samples = 0

    for i, img_file in enumerate(os.listdir(test_images_path)):
        img_path = os.path.join(test_images_path, img_file)
        label_path = os.path.join(test_labels_path, os.path.splitext(img_file)[0] + '.txt')
        
        image = cv2.imread(img_path)
        height, width, _ = image.shape
        results = model(image, device=device, conf = 0.01)
        
        with open(label_path, 'r') as f:
            label_data = f.read().strip().split()
            true_class = int(label_data[0])
            true_bbox = np.array(label_data[1:5], dtype=np.float32)
            true_keypoints = np.array(label_data[5:], dtype=np.float32).reshape(-1, 3)
        # Unnormalize true keypoints
        true_keypoints[:, 0] *= width
        true_keypoints[:, 1] *= height
        
        # Unnormalize true bounding box from (x_center, y_center, w, h) to (x_min, y_min, x_max, y_max)
        true_bbox[0] *= width  # x_center
        true_bbox[1] *= height # y_center
        true_bbox[2] *= width  # width
        true_bbox[3] *= height # height
        
        true_bbox_converted = np.array([
            true_bbox[0] - true_bbox[2] / 2,  # x_min
            true_bbox[1] - true_bbox[3] / 2,  # y_min
            true_bbox[0] + true_bbox[2] / 2,  # x_max
            true_bbox[1] + true_bbox[3] / 2   # y_max
        ])
        
        if not results[0]:
            visualize_results(image, true_bbox_converted, None, true_keypoints, None, yolo=1)
        
        pred_bbox = results[0].boxes.xyxy[0].cpu().numpy()
        pred_keypoints = results[0].keypoints.data[0].cpu().numpy()
        pred_class = results[0].boxes.cls[0].item()
        
        check_keypoint_alignment(true_keypoints, pred_keypoints)
        
        # Calculate IoU for bounding boxes
        iou = calculate_iou(true_bbox_converted, pred_bbox)
        bbox_ious.append(iou)
        
        # Calculate MSE for keypoints
        mse = mean_squared_error(true_keypoints[:, :2], pred_keypoints[:, :2])
        keypoint_errors.append(mse)
        
        
        if pred_class == true_class:
            correct_classifications += 1
        total_samples += 1
        
        # # # Visualize the results for this sample
        # visualize_results(image, true_bbox_converted, pred_bbox, true_keypoints, pred_keypoints, yolo=1)

    mean_iou = np.mean(bbox_ious)
    mean_keypoint_error = np.mean(keypoint_errors)
    classification_accuracy = correct_classifications / total_samples

    print(f"\n{'*'*20} Evaluation Results {'*'*20}")
    print(f"Mean IoU: {mean_iou}")
    print(f"Mean Keypoint Error (MSE): {mean_keypoint_error}")
    print(f"Classification Accuracy: {classification_accuracy}")
    print(f"Total Samples: {total_samples}")
    print(f"{'*'*60}\n")
    
    return mean_iou, mean_keypoint_error, classification_accuracy


models = os.listdir("tennis_pose_estimation")
test_images_path = "dataset_yolo/images/test"
test_labels_path = "dataset_yolo/labels/test"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for model in models:
    model_path = f"tennis_pose_estimation\\{model}\\weights\\best.pt"
    mean_iou, mean_keypoint_error, classification_accuracy = evaluate_yolo_model(model_path, test_images_path, test_labels_path, device)        
    
    # with open("tennis_pose_estimation/eval_results.txt", "a") as f:
    #     f.write(f"\n{'*'*20} Evaluation Results {'*'*20}\n")
    #     f.write(f"Model: {model}\n")
    #     f.write(f"{'-'*60}\n")
    #     f.write(f"Mean BBox IoU: {mean_iou}\n")
    #     f.write(f"Mean Keypoint Error (MSE): {mean_keypoint_error}\n")
    #     f.write(f"Classification Accuracy: {classification_accuracy}\n")
    #     f.write(f"{'*'*60}\n")
# Out:
# 0: 192x320 1 backhand, 56.4ms
# Speed: 5.5ms preprocess, 56.4ms inference, 105.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 22.0ms
# Speed: 2.0ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 18.0ms
# Speed: 1.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 17.6ms
# Speed: 1.0ms preprocess, 17.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 11.2ms
# Speed: 1.0ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 13.5ms
# Speed: 1.5ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.2ms
# Speed: 1.0ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 13.5ms
# Speed: 2.7ms preprocess, 13.5ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 16.2ms
# Speed: 1.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 3.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.1ms
# Speed: 0.0ms preprocess, 12.1ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 backhands, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.3ms
# Speed: 1.0ms preprocess, 12.3ms inference, 1.6ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 3.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.6ms
# Speed: 0.0ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 4.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 11.2ms
# Speed: 1.0ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 3 backhands, 12.5ms
# Speed: 1.6ms preprocess, 12.5ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 backhands, 11.7ms
# Speed: 1.0ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 13.1ms
# Speed: 0.0ms preprocess, 13.1ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 14.1ms
# Speed: 0.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 37.8ms
# Speed: 1.0ms preprocess, 37.8ms inference, 3.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 16.6ms
# Speed: 1.0ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 13.5ms
# Speed: 1.3ms preprocess, 13.5ms inference, 2.8ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.3ms
# Speed: 0.0ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.3ms
# Speed: 1.0ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.7ms
# Speed: 0.0ms preprocess, 12.7ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 16.5ms
# Speed: 1.5ms preprocess, 16.5ms inference, 1.1ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 ready_position, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 17.5ms
# Speed: 1.5ms preprocess, 17.5ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 3 backhands, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 backhands, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 forehand, 12.5ms
# Speed: 1.1ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 11.2ms
# Speed: 1.0ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 ready_position, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 13.2ms
# Speed: 0.0ms preprocess, 13.2ms inference, 1.8ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 backhands, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 backhands, 13.3ms
# Speed: 1.0ms preprocess, 13.3ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 forehand, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 2 forehands, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 forehand, 1 ready_position, 14.2ms
# Speed: 1.0ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 backhands, 1 serve, 1 ready_position, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 backhands, 2 serves, 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 11.3ms
# Speed: 1.0ms preprocess, 11.3ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 backhands, 2 serves, 11.7ms
# Speed: 1.0ms preprocess, 11.7ms inference, 2.1ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 2 serves, 1 ready_position, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 forehand, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 13.3ms
# Speed: 1.0ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 14.0ms
# Speed: 1.4ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 12.9ms
# Speed: 0.0ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 11.7ms
# Speed: 1.0ms preprocess, 11.7ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 18.2ms
# Speed: 1.0ms preprocess, 18.2ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 15.1ms
# Speed: 2.5ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 14.5ms
# Speed: 0.0ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 12.3ms
# Speed: 1.0ms preprocess, 12.3ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 forehand, 12.7ms
# Speed: 2.0ms preprocess, 12.7ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 11.8ms
# Speed: 1.0ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 1 ready_position, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 forehand, 13.2ms
# Speed: 0.0ms preprocess, 13.2ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 13.1ms
# Speed: 0.0ms preprocess, 13.1ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 forehand, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.4ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 13.3ms
# Speed: 1.3ms preprocess, 13.3ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 forehands, 12.9ms
# Speed: 0.0ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 14.0ms
# Speed: 1.5ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 forehands, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 2.6ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 21.9ms
# Speed: 1.0ms preprocess, 21.9ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 11.6ms
# Speed: 1.0ms preprocess, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 14.8ms
# Speed: 0.0ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 1 ready_position, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 13.5ms
# Speed: 0.0ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 16.8ms
# Speed: 1.0ms preprocess, 16.8ms inference, 2.4ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 73.7ms
# Speed: 2.5ms preprocess, 73.7ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 12.8ms
# Speed: 1.5ms preprocess, 12.8ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 1 serve, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 forehand, 11.3ms
# Speed: 1.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 forehand, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 13.5ms
# Speed: 0.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 4 forehands, 1 serve, 1 ready_position, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 4 forehands, 1 serve, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 4 forehands, 1 serve, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 1 ready_position, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 18.0ms
# Speed: 0.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 17.5ms
# Speed: 1.0ms preprocess, 17.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 11.4ms
# Speed: 1.0ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 ready_positions, 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 20.1ms
# Speed: 1.0ms preprocess, 20.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 ready_positions, 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 1.9ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 ready_positions, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 ready_positions, 12.5ms
# Speed: 0.5ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 ready_positions, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 17.7ms
# Speed: 1.0ms preprocess, 17.7ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 22.8ms
# Speed: 1.0ms preprocess, 22.8ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 11.8ms
# Speed: 0.0ms preprocess, 11.8ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 11.6ms
# Speed: 0.0ms preprocess, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 ready_positions, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 14.3ms
# Speed: 1.0ms preprocess, 14.3ms inference, 2.2ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 1 ready_position, 12.9ms
# Speed: 0.0ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 15.5ms
# Speed: 0.0ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.4ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 18.0ms
# Speed: 1.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.2ms
# Speed: 0.0ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 2.1ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 15.1ms
# Speed: 1.5ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 14.7ms
# Speed: 0.0ms preprocess, 14.7ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.5ms
# Speed: 1.1ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 72.0ms
# Speed: 1.5ms preprocess, 72.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 16.3ms
# Speed: 1.0ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.3ms
# Speed: 1.5ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 ready_position, 12.5ms
# Speed: 1.5ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 1 ready_position, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 18.1ms
# Speed: 1.0ms preprocess, 18.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 1 ready_position, 18.5ms
# Speed: 1.5ms preprocess, 18.5ms inference, 1.6ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.3ms
# Speed: 0.0ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 forehands, 1 serve, 1 ready_position, 13.1ms
# Speed: 1.5ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 forehands, 1 serve, 1 ready_position, 18.1ms
# Speed: 1.0ms preprocess, 18.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 forehands, 1 ready_position, 13.7ms
# Speed: 0.0ms preprocess, 13.7ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 ready_position, 11.9ms
# Speed: 0.0ms preprocess, 11.9ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 backhands, 1 forehand, 2 ready_positions, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 forehand, 1 ready_position, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 serve, 1 ready_position, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 backhands, 1 serve, 1 ready_position, 12.6ms
# Speed: 0.0ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 17.6ms
# Speed: 1.6ms preprocess, 17.6ms inference, 3.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 18.1ms
# Speed: 1.0ms preprocess, 18.1ms inference, 2.4ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 14.6ms
# Speed: 1.3ms preprocess, 14.6ms inference, 2.1ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 12.0ms
# Speed: 0.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.6ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 3.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 11.6ms
# Speed: 1.2ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 23.0ms
# Speed: 1.1ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 11.8ms
# Speed: 1.0ms preprocess, 11.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 13.3ms
# Speed: 1.5ms preprocess, 13.3ms inference, 2.1ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 serves, 20.1ms
# Speed: 0.5ms preprocess, 20.1ms inference, 3.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 1 serve, 21.6ms
# Speed: 1.9ms preprocess, 21.6ms inference, 1.6ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 1 serve, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 forehands, 1 serve, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 3.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 1 serve, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 4 serves, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 1 serve, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 1 serve, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 1 serve, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 forehand, 1 serve, 11.5ms
# Speed: 1.5ms preprocess, 11.5ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 backhands, 3 serves, 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 serves, 15.5ms
# Speed: 1.0ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 76.8ms
# Speed: 2.0ms preprocess, 76.8ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 4.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 3 serves, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 serves, 11.5ms
# Speed: 1.5ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 4.3ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 4.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 11.4ms
# Speed: 1.0ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 15.0ms
# Speed: 1.3ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 12.2ms
# Speed: 1.0ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 11.9ms
# Speed: 1.1ms preprocess, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 19.3ms
# Speed: 1.0ms preprocess, 19.3ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 12.5ms
# Speed: 1.4ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 14.8ms
# Speed: 0.0ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 4.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 11.1ms
# Speed: 1.0ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 serve, 12.3ms
# Speed: 1.0ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 backhands, 1 serve, 11.5ms
# Speed: 1.1ms preprocess, 11.5ms inference, 4.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 serve, 11.7ms
# Speed: 2.0ms preprocess, 11.7ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 forehand, 2 serves, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 3.3ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 serve, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 backhands, 1 serve, 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 serve, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 forehand, 1 serve, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.2ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 2 backhands, 1 forehand, 1 serve, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 forehand, 1 serve, 91.4ms
# Speed: 2.0ms preprocess, 91.4ms inference, 3.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 serve, 13.1ms
# Speed: 0.0ms preprocess, 13.1ms inference, 1.5ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 2 serves, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 1 serve, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)
#
# 0: 192x320 1 backhand, 2 serves, 12.5ms
# Speed: 0.5ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 192, 320)
#
# ******************** Evaluation Results ********************
# Mean IoU: 0.8506637047088413
# Mean Keypoint Error (MSE): 100.5538558959961
# Classification Accuracy: 0.98
# Total Samples: 300
# ************************************************************
#
#
# 0: 384x640 1 backhand, 37.2ms
# Speed: 2.5ms preprocess, 37.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 12.1ms
# Speed: 1.0ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 12.8ms
# Speed: 1.0ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 13.7ms
# Speed: 2.0ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 24.0ms
# Speed: 1.0ms preprocess, 24.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 18.5ms
# Speed: 1.5ms preprocess, 18.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 16.1ms
# Speed: 1.0ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 12.0ms
# Speed: 1.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 18.2ms
# Speed: 1.5ms preprocess, 18.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 17.0ms
# Speed: 1.5ms preprocess, 17.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 20.6ms
# Speed: 1.0ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 18.6ms
# Speed: 1.0ms preprocess, 18.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 21.1ms
# Speed: 2.0ms preprocess, 21.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 22.0ms
# Speed: 1.5ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 22.4ms
# Speed: 1.0ms preprocess, 22.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 65.6ms
# Speed: 1.0ms preprocess, 65.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 19.7ms
# Speed: 1.0ms preprocess, 19.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 51.5ms
# Speed: 2.0ms preprocess, 51.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 12.5ms
# Speed: 1.5ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 63.6ms
# Speed: 2.0ms preprocess, 63.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 19.0ms
# Speed: 1.2ms preprocess, 19.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 17.6ms
# Speed: 1.0ms preprocess, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 17.6ms
# Speed: 2.2ms preprocess, 17.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 16.5ms
# Speed: 1.0ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 23.6ms
# Speed: 1.0ms preprocess, 23.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 15.6ms
# Speed: 1.0ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 1 serve, 22.9ms
# Speed: 2.0ms preprocess, 22.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 23.0ms
# Speed: 1.0ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 21.1ms
# Speed: 2.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 18.0ms
# Speed: 1.0ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 111.4ms
# Speed: 1.0ms preprocess, 111.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 21.1ms
# Speed: 2.0ms preprocess, 21.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 13.3ms
# Speed: 1.0ms preprocess, 13.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 17.5ms
# Speed: 1.0ms preprocess, 17.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 backhands, 15.4ms
# Speed: 1.6ms preprocess, 15.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 backhands, 1 forehand, 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 2 serves, 11.6ms
# ...
# Speed: 1.0ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 1 ready_position, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 15.6ms
# Speed: 1.5ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forehand, 2 ready_positions, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 17.4ms
# Speed: 1.0ms preprocess, 17.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 13.7ms
# Speed: 2.0ms preprocess, 13.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 20.4ms
# Speed: 1.0ms preprocess, 20.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 27.3ms
# Speed: 1.0ms preprocess, 27.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 1 ready_position, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 12.2ms
# Speed: 1.0ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 16.5ms
# Speed: 1.0ms preprocess, 16.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 backhands, 2 forehands, 1 serve, 1 ready_position, 18.5ms
# Speed: 1.0ms preprocess, 18.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 backhands, 2 forehands, 5 ready_positions, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 forehands, 1 ready_position, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 forehands, 1 ready_position, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 1 ready_position, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ready_position, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 backhands, 4 forehands, 2 ready_positions, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 4 forehands, 1 serve, 2 ready_positions, 29.2ms
# Speed: 2.0ms preprocess, 29.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 backhands, 2 forehands, 1 serve, 1 ready_position, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 backhands, 3 forehands, 1 ready_position, 21.1ms
# Speed: 0.5ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 backhands, 3 forehands, 1 ready_position, 19.1ms
# Speed: 1.0ms preprocess, 19.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 5 forehands, 1 ready_position, 17.3ms
# Speed: 1.0ms preprocess, 17.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 4 forehands, 1 serve, 1 ready_position, 18.1ms
# Speed: 1.0ms preprocess, 18.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 backhands, 3 forehands, 3 serves, 2 ready_positions, 19.2ms
# Speed: 1.0ms preprocess, 19.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 backhands, 2 forehands, 3 serves, 2 ready_positions, 13.6ms
# Speed: 0.5ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 backhands, 3 forehands, 2 serves, 2 ready_positions, 17.2ms
# Speed: 1.0ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 backhands, 1 forehand, 1 ready_position, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 serves, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 13.5ms
# Speed: 1.5ms preprocess, 13.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 26.5ms
# Speed: 1.0ms preprocess, 26.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 12.3ms
# Speed: 1.0ms preprocess, 12.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 12.8ms
# Speed: 1.0ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 15.4ms
# Speed: 1.0ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 1 serve, 18.6ms
# Speed: 1.0ms preprocess, 18.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 14.6ms
# Speed: 1.5ms preprocess, 14.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 1 serve, 12.7ms
# Speed: 2.0ms preprocess, 12.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 1 serve, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 5 forehands, 4 serves, 13.1ms
# Speed: 1.5ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 1 serve, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 4 forehands, 4 serves, 16.6ms
# Speed: 1.1ms preprocess, 16.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 5 forehands, 3 serves, 13.9ms
# Speed: 1.0ms preprocess, 13.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 4 forehands, 5 serves, 21.7ms
# Speed: 1.0ms preprocess, 21.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 1 serve, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 1 serve, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 1 forehand, 5 serves, 14.3ms
# Speed: 1.0ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 1 forehand, 4 serves, 13.6ms
# Speed: 1.5ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 29.6ms
# Speed: 1.0ms preprocess, 29.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 1 forehand, 1 serve, 12.7ms
# Speed: 1.0ms preprocess, 12.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 1 forehand, 1 serve, 16.5ms
# Speed: 2.3ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 1 forehand, 1 serve, 15.8ms
# Speed: 1.2ms preprocess, 15.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forehand, 4 serves, 18.1ms
# Speed: 1.0ms preprocess, 18.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 forehand, 2 serves, 18.6ms
# Speed: 1.0ms preprocess, 18.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 1 serve, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 27.4ms
# Speed: 1.0ms preprocess, 27.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 2 forehands, 1 serve, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 backhand, 1 forehand, 1 serve, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 1 forehand, 1 serve, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 1 forehand, 1 serve, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 1 forehand, 1 serve, 15.8ms
# Speed: 1.0ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 1 forehand, 1 serve, 13.4ms
# Speed: 2.0ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 1 serve, 12.5ms
# Speed: 1.5ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 12.8ms
# Speed: 1.0ms preprocess, 12.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 serve, 32.1ms
# Speed: 1.0ms preprocess, 32.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 4 forehands, 8 serves, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 backhands, 5 forehands, 6 serves, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 3 forehands, 1 serve, 16.5ms
# Speed: 1.1ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 backhands, 5 forehands, 3 serves, 30.8ms
# Speed: 1.0ms preprocess, 30.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 4 forehands, 2 serves, 14.5ms
# Speed: 1.5ms preprocess, 14.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 backhands, 2 forehands, 3 serves, 1 ready_position, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 backhands, 2 forehands, 3 serves, 1 ready_position, 15.1ms
# Speed: 0.5ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 backhands, 2 forehands, 2 serves, 14.6ms
# Speed: 1.0ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 backhands, 1 forehand, 1 serve, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 backhands, 2 forehands, 2 serves, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 backhands, 2 forehands, 2 serves, 13.1ms
# Speed: 2.1ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 backhands, 2 forehands, 1 serve, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 backhands, 1 forehand, 4 serves, 1 ready_position, 25.4ms
# Speed: 1.0ms preprocess, 25.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 backhands, 1 forehand, 4 serves, 1 ready_position, 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 backhands, 2 forehands, 2 serves, 13.5ms
# Speed: 1.5ms preprocess, 13.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 backhands, 1 forehand, 2 serves, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 backhands, 2 forehands, 3 serves, 14.3ms
# Speed: 1.0ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 backhands, 2 forehands, 4 serves, 16.9ms
# Speed: 2.5ms preprocess, 16.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ******************** Evaluation Results ********************
# Mean IoU: 0.845020405424844
# Mean Keypoint Error (MSE): 78.40884399414062
# Classification Accuracy: 0.99
# Total Samples: 300
# ************************************************************
